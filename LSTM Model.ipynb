# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
start ='2010-01-01'
end ='2019-12-31'

# %%
# here we read the data from datareader function its provide data from top fincaial web like yahoo fincace
df =data.DataReader('AAPL','yahoo', start, end)
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2009-12-31  7.619643  7.520000  7.611786  7.526071  352410800.0   6.462008
# 2010-01-04  7.660714  7.585000  7.622500  7.643214  493729600.0   6.562591
# 2010-01-05  7.699643  7.616071  7.664286  7.656429  601904800.0   6.573935
# 2010-01-06  7.686786  7.526786  7.656429  7.534643  552160000.0   6.469369
# 2010-01-07  7.571429  7.466071  7.562500  7.520714  477131200.0   6.457407

# %%
df.tail()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2019-12-24  71.222504  70.730003  71.172501  71.067497   48478800.0  70.129517
# 2019-12-26  72.495003  71.175003  71.205002  72.477501   93121200.0  71.520905
# 2019-12-27  73.492500  72.029999  72.779999  72.449997  146266000.0  71.493759
# 2019-12-30  73.172501  71.305000  72.364998  72.879997  144114400.0  71.918083
# 2019-12-31  73.419998  72.379997  72.482498  73.412498  100805600.0  72.443558

# %%
# here we make index from 0-n number
df= df.reset_index()
df.head()
# Out:
#         Date      High       Low      Open     Close       Volume  Adj Close
# 0 2009-12-31  7.619643  7.520000  7.611786  7.526071  352410800.0   6.462008
# 1 2010-01-04  7.660714  7.585000  7.622500  7.643214  493729600.0   6.562591
# 2 2010-01-05  7.699643  7.616071  7.664286  7.656429  601904800.0   6.573935
# 3 2010-01-06  7.686786  7.526786  7.656429  7.534643  552160000.0   6.469369
# 4 2010-01-07  7.571429  7.466071  7.562500  7.520714  477131200.0   6.457407

# %%
# now drop unneccessary coloums
df =df.drop(['Date','Adj Close'], axis= 1)
df.head()
# Out:
#        High       Low      Open     Close       Volume
# 0  7.619643  7.520000  7.611786  7.526071  352410800.0
# 1  7.660714  7.585000  7.622500  7.643214  493729600.0
# 2  7.699643  7.616071  7.664286  7.656429  601904800.0
# 3  7.686786  7.526786  7.656429  7.534643  552160000.0
# 4  7.571429  7.466071  7.562500  7.520714  477131200.0

# %%
# plot graph of closing price
plt.plot(df.Close)

# %%
df
# Out:
#            High        Low       Open      Close       Volume
# 0      7.619643   7.520000   7.611786   7.526071  352410800.0
# 1      7.660714   7.585000   7.622500   7.643214  493729600.0
# 2      7.699643   7.616071   7.664286   7.656429  601904800.0
# 3      7.686786   7.526786   7.656429   7.534643  552160000.0
# 4      7.571429   7.466071   7.562500   7.520714  477131200.0
# ...         ...        ...        ...        ...          ...
# 2512  71.222504  70.730003  71.172501  71.067497   48478800.0
# 2513  72.495003  71.175003  71.205002  72.477501   93121200.0
# 2514  73.492500  72.029999  72.779999  72.449997  146266000.0
# 2515  73.172501  71.305000  72.364998  72.879997  144114400.0
# 2516  73.419998  72.379997  72.482498  73.412498  100805600.0
#
# [2517 rows x 5 columns]

# %%
# we find average of moving 100 value
ma100 =df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2512    59.401700
# 2513    59.643125
# 2514    59.875125
# 2515    60.106325
# 2516    60.331875
# Name: Close, Length: 2517, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma200 =df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2512    54.261513
# 2513    54.396763
# 2514    54.529350
# 2515    54.661100
# 2516    54.793137
# Name: Close, Length: 2517, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma200,'g')

# %%
df.shape
# Out:
# (2517, 5)

# %% [markdown]
# # Spliting Data into taining and testing

# %%
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1761, 1)
# (756, 1)

# %%
data_training.head()
# Out:
#       Close
# 0  7.526071
# 1  7.643214
# 2  7.656429
# 3  7.534643
# 4  7.520714

# %%
data_testing.head()
# Out:
#           Close
# 1761  29.182501
# 1762  28.955000
# 1763  29.037500
# 1764  29.004999
# 1765  29.152500

# %%
from sklearn.preprocessing import MinMaxScaler 
scaler =MinMaxScaler(feature_range=(0,1))

# %%
data_training_array =scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.02527908],
#        [0.02971782],
#        [0.03021854],
#        ...,
#        [0.84388656],
#        [0.85089656],
#        [0.84616011]])

# %%
data_training_array.shape
# Out:
# (1761, 1)

# %%
x_train =[]
y_train =[]
for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])
    
#now conver this x_train and y_train data into numpy array
x_train, y_train =np.array(x_train), np.array(y_train)

# %% [markdown]
# # ML model

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model =Sequential()
model.add(LSTM(units =50, activation ='relu', return_sequences =True, input_shape =(x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units =60, activation ='relu', return_sequences =True))
model.add(Dropout(0.3))

model.add(LSTM(units =80, activation ='relu', return_sequences =True ))
model.add(Dropout(0.4))

model.add(LSTM(units =120, activation ='relu'))
model.add(Dropout(0.5))

model.add(Dense(units =1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 50)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 60)           26640
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 60)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100, 80)           45120
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 80)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120)               96480
# ...

# %%
model.compile(optimizer ='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs =50)
# Out:
# Epoch 1/50
# 52/52 [==============================] - 15s 183ms/step - loss: 0.0682
# Epoch 2/50
# 52/52 [==============================] - 9s 171ms/step - loss: 0.0145
# Epoch 3/50
# 52/52 [==============================] - 9s 176ms/step - loss: 0.0111
# Epoch 4/50
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0098
# Epoch 5/50
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0103
# Epoch 6/50
# 52/52 [==============================] - 11s 215ms/step - loss: 0.0099
# Epoch 7/50
# 52/52 [==============================] - 11s 219ms/step - loss: 0.0100
# Epoch 8/50
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0079
# Epoch 9/50
# 52/52 [==============================] - 11s 213ms/step - loss: 0.0076
# Epoch 10/50
# 52/52 [==============================] - 11s 210ms/step - loss: 0.0076
# Epoch 11/50
# 52/52 [==============================] - 12s 236ms/step - loss: 0.0068
# Epoch 12/50
# ...

# %%
model.save('keras_model.h5')

# %%
data_testing.head()
# Out:
#           Close
# 1761  29.182501
# 1762  28.955000
# 1763  29.037500
# 1764  29.004999
# 1765  29.152500

# %%
data_training.tail(100)
# Out:
#           Close
# 1661  27.092501
# 1662  27.202499
# 1663  27.000000
# 1664  26.982500
# 1665  27.045000
# ...         ...
# 1756  29.264999
# 1757  29.072500
# 1758  29.129999
# 1759  29.315001
# 1760  29.190001
#
# [100 rows x 1 columns]

# %%
past_100_days =data_training.tail(100)

# %%
# now we connect the past_100_days data to testing data
final_df =past_100_days.append(data_testing ,ignore_index=True)

# %%
final_df.head()
# Out:
#        Close
# 0  27.092501
# 1  27.202499
# 2  27.000000
# 3  26.982500
# 4  27.045000

# %%
input_data =scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.0275037 ],
#        [0.02981315],
#        [0.02556164],
#        [0.02519422],
#        [0.02650642],
#        [0.03332987],
#        [0.03280496],
#        [0.03196517],
#        [0.03123034],
#        [0.0327    ],
#        [0.02823853],
#        [0.0300231 ],
#        [0.02571909],
#        [0.02330465],
#        [0.01999793],
#        [0.01936806],
#        [0.01506405],
#        [0.01558892],
#        [0.01889569],
#        [0.02414448],
#        [0.02398698],
#        [0.0274512 ],
#        [0.01254461],
#        [0.        ],
#        [0.01212474],
#        [0.02529918],
#        [0.04534957],
#        [0.065295  ],
#        [0.06188327],
#        [0.05484991],
#        [0.05479741],
#        [0.05469245],
#        [0.06030866],
#        [0.05028345],
#        [0.05117573],
#        [0.05227797],
#        [0.05679194],
#        [0.04750159],
#        [0.05206806],
#        [0.04928616],
#        [0.0518056 ],
#        [0.05206806],
#        [0.05647702],
# ...

# %%
input_data.shape
# Out:
# (856, 1)

# %%
# now we make x_test and y_test 
x_test =[]
y_test =[]
for i in range (100, input_data.shape[0]):
    x_test.append(input_data[i-100: i])
    y_test.append(input_data[i,0])

# %%
x_test, y_test =np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (756, 100, 1)
# (756,)

# %% [markdown]
# # making prediction

# %%
y_predicted =model.predict(x_test)

# %%
y_predicted.shape
# Out:
# (756, 1)

# %%
y_test
# Out:
# array([0.07138362, 0.06660719, 0.06833931, 0.06765694, 0.07075375,
#        0.07757719, 0.08324586, 0.08387573, 0.08723495, 0.08461056,
#        0.08350831, 0.08854715, 0.08849465, 0.08739241, 0.08854715,
#        0.08896706, 0.08838969, 0.09841487, 0.09872982, 0.09878228,
#        0.09710267, 0.09563301, 0.13447409, 0.13331935, 0.1362062 ,
#        0.14255719, 0.14906573, 0.15174258, 0.15373715, 0.15216249,
#        0.15830357, 0.16738404, 0.1699559 , 0.16911615, 0.17105818,
#        0.17620198, 0.178354  , 0.17530969, 0.17599206, 0.17740917,
#        0.17772417, 0.19242073, 0.1880643 , 0.19236827, 0.19005879,
#        0.19100361, 0.18827421, 0.18659456, 0.18900904, 0.18932396,
#        0.18822176, 0.19593749, 0.19714469, 0.19347055, 0.20118628,
#        0.19268318, 0.20097628, 0.19835189, 0.19688223, 0.19814197,
#        0.21346844, 0.21514801, 0.21415073, 0.21273361, 0.21294353,
#        0.21855977, 0.21462318, 0.21273361, 0.21105396, 0.21016167,
# ...

# %%
y_predicted
# Out:
# array([[0.13689785],
#        [0.13773105],
#        [0.13842458],
#        [0.13897237],
#        [0.1393834 ],
#        [0.13968265],
#        [0.1399222 ],
#        [0.14017437],
#        [0.14050427],
#        [0.14095846],
#        [0.14155257],
#        [0.14226711],
#        [0.14307582],
#        [0.14395091],
#        [0.14485526],
#        [0.14575222],
#        [0.14661211],
#        [0.14741054],
#        [0.14815418],
#        [0.14887312],
#        [0.14959112],
#        [0.1503172 ],
#        [0.1510438 ],
#        [0.15185869],
#        [0.1528847 ],
#        [0.15420367],
#        [0.15586397],
#        [0.1578864 ],
#        [0.16025783],
#        [0.16292876],
#        [0.16581304],
#        [0.16878463],
#        [0.17177325],
#        [0.17473015],
#        [0.1776501 ],
#        [0.18051592],
#        [0.18331857],
#        [0.1860562 ],
#        [0.18871692],
#        [0.19128332],
#        [0.19373994],
#        [0.19607332],
#        [0.19831017],
# ...

# %%
scaler.scale_
# Out:
# array([0.02099517])

# %%
scale_factor =1/0.02099517
y_predicted =y_predicted *scale_factor
y_test =y_test *scale_factor

# %%
plt.figure(figsize =(12,6))
plt.plot(y_test,'b',label="Orginal Price")
plt.plot(y_predicted, 'r',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
